# %% [markdown]
# <a href="https://colab.research.google.com/github/gnaneswar-18/pca-2/blob/main/pca2_ipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from skimage import data

image = data.camera()
plt.imshow(image, cmap='gray')
plt.title("Original Image")
plt.show()

x = image.reshape(-1, image.shape[1])

def apply_pca(X, n_components):
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X)
    X_reconstructed = pca.inverse_transform(X_pca)
    return X_reconstructed

n_components_list = [5, 20, 50, 100]
reconstructed_images = [apply_pca(x, n) for n in n_components_list]

reconstructed_images = [img.reshape(image.shape) for img in reconstructed_images]

fig, axes = plt.subplots(1, len(n_components_list) + 1, figsize=(15, 5))

axes[0].imshow(image, cmap='gray')
axes[0].set_title("Original Image")
axes[0].axis('off')

for i, n in enumerate(n_components_list):
    axes[i + 1].imshow(reconstructed_images[i], cmap='gray')
    axes[i + 1].set_title(f"PCA with {n} components")
    axes[i + 1].axis('off')

plt.show()
